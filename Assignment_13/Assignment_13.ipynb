# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 27.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ultralytics import YOLO
#
# File c:\Users\abdul\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\__init__.py:13
#      10 if not os.environ.get("OMP_NUM_THREADS"):
#      11     os.environ["OMP_NUM_THREADS"] = "1"  # default for reduced CPU utilization during training
# ---> 13 from ultralytics.utils import ASSETS, SETTINGS
#      14 from ultralytics.utils.checks import check_yolo as checks
#      15 from ultralytics.utils.downloads import download
#
# File c:\Users\abdul\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\utils\__init__.py:26
#      24 import cv2
#      25 import numpy as np
# ---> 26 import torch
#      28 from ultralytics import __version__
#      29 from ultralytics.utils.git import GitRepo
#
# ...

# %%
model = YOLO("yolo11n.pt")

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import zipfile

car_lincence_path = zipfile.ZipFile("/content/drive/MyDrive/License-Plate-Data.zip")
car_lincence_path.extractall("")


seat_belt_path = zipfile.ZipFile("/content/drive/MyDrive/Seat belt detection.v3i.yolov11.zip")
seat_belt_path.extractall("/content/seat_belt")

# %%
model.train(data="/content/License-Plate-Data/data.yaml", epochs=15, imgsz=240)
# Out:
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model2 = YOLO("yolo11n.pt")

# %%
model2.train(data="/content/seat_belt/data.yaml", epochs= 15, imgsz=240)
# Out:
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model.save("License_plate_detection_model.pt")

# %%
model2.save("seat_belt_detection_model.pt")

# %%
from IPython.display import Image

# %%
Image("/content/runs/detect/train/results.png")

# %%
Image("/content/runs/detect/train2/results.png")

# %%
seatbelt_model = YOLO("/content/runs/detect/train/weights/best.pt")
plate_model = YOLO("/content/runs/detect/train2/weights/best.pt")

# %%
result = seatbelt_model.predict("/content/seat_belt/images/test/IMG_20230617_153644.jpg",)[0]
plate_result = plate_model.predict("/content/License-Plate-Data/images/test/IMG_20230617_153644.jpg",)[0]

# %%
plate_result.show()

# %%
result.show()
