# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, root_mean_squared_error, mean_squared_error

# %%
data = pd.read_csv("Housing.csv")

# %%
df= pd.DataFrame(data)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.sample(n=3
)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 411  3430000  2145         3          1        3      yes        no       no
# 115  6020000  8000         3          1        1      yes       yes      yes
# 428  3325000  4040         2          1        1      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 411              no              no        0      yes        furnished
# 115              no             yes        2      yes   semi-furnished
# 428              no              no        1       no      unfurnished

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
for i in df.select_dtypes(include="object").columns:
    sns.countplot(df,x=i, palette="Paired")
    plt.show()
# Out:
# C:\Users\abdul\AppData\Local\Temp\ipykernel_6404\1984889198.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x=i, palette="Paired")
# C:\Users\abdul\AppData\Local\Temp\ipykernel_6404\1984889198.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x=i, palette="Paired")
# C:\Users\abdul\AppData\Local\Temp\ipykernel_6404\1984889198.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x=i, palette="Paired")
# C:\Users\abdul\AppData\Local\Temp\ipykernel_6404\1984889198.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x=i, palette="Paired")
# C:\Users\abdul\AppData\Local\Temp\ipykernel_6404\1984889198.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x=i, palette="Paired")
# C:\Users\abdul\AppData\Local\Temp\ipykernel_6404\1984889198.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x=i, palette="Paired")
# C:\Users\abdul\AppData\Local\Temp\ipykernel_6404\1984889198.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x=i, palette="Paired")

# %%
# Calculating Correlation of Price with numerical columns
for i in df.select_dtypes(include='number').columns:
    print(f"Correlation of {i} with Price: {df[i].corr(df['price'])}")
# Out:
# Correlation of price with Price: 1.0
# Correlation of area with Price: 0.5359973457780797
# Correlation of bedrooms with Price: 0.36649402577386875
# Correlation of bathrooms with Price: 0.5175453394550112
# Correlation of stories with Price: 0.42071236618861657
# Correlation of parking with Price: 0.38439364863572595

# %%
for i in df.select_dtypes(include='object').columns:
    sns.barplot(data=df,x=i,y='price')
    plt.show()

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
cate_col = df.select_dtypes(include="object").columns
cate_col = cate_col.drop("furnishingstatus")

# %%
cate_col
# Out:
# Index(['mainroad', 'guestroom', 'basement', 'hotwaterheating',
#        'airconditioning', 'prefarea'],
#       dtype='object')

# %%
for i in cate_col:
    df[i]= df[i].map({"yes":1, "no":0})

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
df['furnishingstatus'].unique()
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %%
df['furnishingstatus'] = df['furnishingstatus'].map({"furnished":2, "semi-furnished":1,"unfurnished":0})

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 2
# 1                 2
# 2                 1
# 3                 2
# 4                 2

# %%
X = df.drop(['price'], axis=1)
y_true=df['price']

# %%
X_train, X_test,y_train,y_test = train_test_split(X, y_true, test_size=0.2, random_state=320406)

# %%
lr_model = LinearRegression()

# %%
lr_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr_model.coef_)
print(lr_model.intercept_)
# Out:
# [2.31709111e+02 1.53612990e+05 1.01806943e+06 3.93177650e+05
#  4.21355457e+05 3.51270443e+05 3.36304188e+05 9.27026532e+05
#  8.90745010e+05 3.77360323e+05 6.67501270e+05 2.40753621e+05]
# -360332.4363664286

# %%
area = float(input('Enter Area in sq-ft:'))
bedrooms = int(input('Enter bedrooms:'))
bathrooms = int(input('Enter bathrooms: '))
stories = int(input("Enter stories: "))

mainroad = input("Do it have Main road [yes/no]: ")
mainroad = 1 if mainroad=='yes' else 0

guestroom = input("Do it have Guest room [yes/no]: ")
guestroom = 1 if guestroom=='yes' else 0

basement = input("Do it have Basement [yes/no]: ")
basement = 1 if basement=='yes' else 0

hotwaterheating = input("Do it have hot water [yes/no]: ")
hotwaterheating = 1 if hotwaterheating=='yes' else 0

airconditioning = input("Do it have airconditioning [yes/no]: ")
airconditioning = 1 if airconditioning=='yes' else 0

parking = int(input("Enter parking:"))

prefarea = input("Do it have prefarea [yes/no]: ")
prefarea = 1 if prefarea=='yes' else 0

furnishing_status_mapping = {'furnished':2, 'semi-furnished':1, 'unfurnished':0}

furnishingstatus = input('Enter furnishing status: ')
furnishingstatus = furnishing_status_mapping[furnishingstatus]

price_pred = lr_model.predict([[area, bedrooms, bathrooms, stories,mainroad, guestroom, basement, hotwaterheating, airconditioning, parking, prefarea, furnishingstatus]])

print('Predicted price: ', price_pred[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 area = float(input('Enter Area in sq-ft:'))
#       2 bedrooms = int(input('Enter bedrooms:'))
#       3 bathrooms = int(input('Enter bathrooms: '))
#
# ValueError: could not convert string to float: ''

# %%
import joblib

# %%
joblib.dump(lr_model, "House_pred.pkl")
# Out:
# ['House_pred.pkl']
